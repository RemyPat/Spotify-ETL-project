# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import spotipy
#       2 from spotipy.oauth2 import SpotifyClientCredentials
#       3 import pandas as pd
#
# ModuleNotFoundError: No module named 'spotipy'

# %%
#add your keys here
client_credentials_manager = SpotifyClientCredentials(client_id="eb05b082bfb94add816e773beec82a1e", client_secret="11ebc60987cd4a6ba51c269bd056e3db")

# %%
sp=spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
playlist_link="https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF"

# %%
playlist_ID=playlist_link.split("/")[-1]
playlist_ID
# Out:
# '37i9dQZEVXbNG2KDcFcKOF'

# %%
data=sp.playlist_tracks(playlist_ID)
data
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXbNG2KDcFcKOF/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2024-08-30T09:42:25Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
# ...

# %%
data["items"][2]['track']['album']['name']
# Out:
# 'Please Please Please'

# %%
data["items"][2]['track']['album']['id']
# Out:
# '5bBaoign62r1i7OV8w7mi9'

# %%
data["items"][2]['track']['album']['release_date']
# Out:
# '2024-06-06'

# %%
data["items"][2]['track']['album']['total_tracks']
# Out:
# 2

# %%
data["items"][2]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/5bBaoign62r1i7OV8w7mi9'

# %%
album_list=[]
for row in data["items"]:
    album_id=row['track']['album']['id']
    album_name=row['track']['album']['name']
    album_release_date=row['track']['album']['release_date']
    album_total_tracks=row['track']['album']['total_tracks']
    album_url=row['track']['album']['external_urls']['spotify']
    album_element={'album_id':album_id,'album_name':album_name,'album_release_date':album_release_date,'album_total_tracks':album_total_tracks,'album_url':album_url}
    album_list.append(album_element)

album_list

# %%
artist_list=[]
for row in data["items"]:
    for key,value in row.items():
        if key=='track':
            for artist in value['artists']:
                artist_id=artist['id']
                artist_name=artist['name']
                artist_url=artist['external_urls']['spotify']
                artist_dict={'artist_id':artist_id,'artist_name':artist_name,'artist_url':artist_url}
                artist_list.append(artist_dict)
artist_list

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)
# Out:
# {'preview_url': None,
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
# ...
